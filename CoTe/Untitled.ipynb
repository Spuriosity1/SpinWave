# %%
# import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
raw_CSTOCK = np.genfromtxt("Stock_raw/2d_data.csv")

def getxy(cmin, cmax):
    Y,X= np.where(np.logical_and(raw_CSTOCK>cmin,raw_CSTOCK<cmax))
    X = X*3.8/raw_CSTOCK.shape[0]
    Y = 10*(1-Y/raw_CSTOCK.shape[1])
    return X, Y

plt.pcolormesh(np.linspace(0,3.8,raw.shape[1]),np.linspace(0,10,raw.shape[0]),raw[::-1,:],vmin=0,vmax=1, shading='nearest')
plt.plot(X,Y, 'ro', ms=1)

# %%
Qvals = np.linspace(0,3.8,raw.shape[1])

for i in [11, 20, 34, 39]:
    plt.plot(np.linspace(0,10,raw.shape[0]), raw[::-1,i],label=Qvals[i])
plt.ylim([0,1.2])
plt.legend()
